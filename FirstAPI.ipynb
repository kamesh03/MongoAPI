# %%
1+2

# %%
print("Kamesh")

# %%
a=10

# %%
b=15

# %%
a+b
# Out:
# 25

# %%
c=18

# %%
a+b+c
# Out:
# 43

# %%
sort={1,2,3}

# %%
type(sort)

# %%
sort=[1,2,3]

# %%
type(sort)

# %%
sort=(1,2,3)

# %%
type(sort)

# %%
sort=({1,2,3},{23,4})

# %%
type(sort)

# %%
a

# %%
b

# %%
sort

# %%
sort=[{1,2,3},{23,4}]

# %%
type(sort)
